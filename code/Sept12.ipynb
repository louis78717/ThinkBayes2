# %%
from thinkbayes2 import *
dice6 = Pmf(range(1,7))
threeRoll = dice6+dice6+dice6
thinkplot.Hist(threeRoll)

# %%
threeDiceCdf = threeRoll.Max(3)
thinkplot.Cdf(threeDiceCdf)
# Out:
# ...
# {'yscale': 'linear', 'xscale': 'linear'}

# %%
from dice import Dice
d={4:2, 6:6, 8:3, 10:2, 12:4, 20:4}
pmf=Dice(d)
thinkplot.Hist(pmf)

# %%
pmf.Update(6)
thinkplot.Hist(pmf)
